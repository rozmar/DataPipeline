# %%
import numpy as np
import matplotlib.pyplot as plt
import datajoint as dj
import pandas as pd
from pipeline import pipeline_tools, lab, experiment, behavioranal, ephys_patch, ephysanal
dj.conn()
# %matplotlib inline
from plot.plot_ephys import *
# Out:
# Connecting rozmar@mesoscale-activity.datajoint.io:3306

# %%
plot_IV(wr_name = 'FOR04', cellnum = 1, ivnum = 0,IVsweepstoplot = [0,14])

# %%
plot_AP(wr_name = 'FOR04', cellnum = 1, timeedges = [50, 58.5], timeback = .0015, timeforward = .003, moving_n_diff = 5)
# Out:
# /home/rozmar/Scripts/Python/DataPipeline/plot/plot_ephys.py:132: RuntimeWarning: Mean of empty slice
#   dy = np.squeeze(np.asarray(np.nanmean(np.asmatrix([np.concatenate([[np.nan],dy]),np.concatenate([dy,[np.nan]])]),0).transpose()))
# /home/rozmar/Scripts/Python/DataPipeline/plot/plot_ephys.py:132: RuntimeWarning: Mean of empty slice
#   dy = np.squeeze(np.asarray(np.nanmean(np.asmatrix([np.concatenate([[np.nan],dy]),np.concatenate([dy,[np.nan]])]),0).transpose()))

# %%
plot_time_interval(wr_name = 'FOR04', cellnum = 1, timeedges = [0, 1500],ylimits_response = [-80, 40],plotRS = True)

# %%
plot_time_interval(wr_name = 'FOR04', cellnum = 1, timeedges = [0, 400],ylimits_response = [-80, 40])

# %%
plot_time_interval(wr_name = 'FOR04', cellnum = 1, timeedges = [297, 299],ylimits_response = [-80, 40])

# %%
plot_time_interval(wr_name = 'FOR04', cellnum = 1, timeedges = [665, 965],ylimits_response = [-80, 40])

# %%
plot_time_interval(wr_name = 'FOR04', cellnum = 1, timeedges = [860, 870],ylimits_response = [-60, 30])
