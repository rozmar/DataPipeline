# %%
import napari
import caiman
import pickle
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
movie_dir_now='/home/rozmar/Data/Voltage_imaging/VolPy/Voltage_rig_1P/rozsam/20200725-anm466771/40x_1xtube_7A2'

motioncorr_1 = pickle.load(open(os.path.join(movie_dir_now, 'motion_corr_1.pickle'), 'rb'))

# %%
plt.imshow(motioncorr_1['templates_rig'][-10])

# %%
plt.imshow(motioncorr_1['templates_rig'][-10])

# %%
plt.imshow(motioncorr_1['templates_rig'][10])

# %%
len(motioncorr_1['templates_rig'])
# Out:
# 70
